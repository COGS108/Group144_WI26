# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
#  Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is 0
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
#
#
#
#
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# - Lydia Chin: Writing, Data curation
# - Jeffrey Kang: Writing, Software
# - Peter Little: Writing, Background Research, Software
# - Chaylen Nguyen-Tran: Writing, Software, Background Research, Project administration
# - Ziqing Zhu: Writing, Visualization

# %% [markdown]
# # Research Question

# %% [markdown]
# Which academic and experiential factors (e.g., GPA, internship experience, research experience) are most predictive of internship outcomes in the technology industry?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Since freshman year, we've been given lots of advice on the multiple factors that go into getting a job post-graduation. However, some mentors give mixed advice, and we want to pinpoint exactly what combination of GPA, professional experience, and extracurriculars makes for the highest likelihood of employment post-graduation. And expanding on this question, we want to tackle this across multiple fields and see whether different students should prioritize certain variables for their own success. After light research, we found many sources that took into account variables such as GPA, internship experience, project experience, technical skills, and soft skills, such as behavioral interviews and networking. While many of these factors may be difficult to quantify in our project, they give us a good starting point for where we should look.
#
# One of the first papers we've looked into was from Bowling Green State University<sup><a href="#fn1" id="ref1">1</a></sup>, which largely studied undergraduate business students for the correlation between academic and co-curricular factors and full-time job placement post graduation and starting salaries. Some of their findings were that internship experience, GPA, and area of study were the most accurate predictors for full-time employment after graduation. Many of these same factors had a high correlation with starting salary; however, surprisingly, participation in college organizations showed some correlation, but to a weaker extent. Another paper from the Journal of Vocational Behavior<sup><a href="#fn2" id="ref2">2</a></sup> studied the effectiveness of internship experiences on work placement post graduation. While this paper had some interesting findings questioning the effectiveness of internships, they lacked a data-driven approach that would be of much use to our project. Going forward, it would be beneficial to look for research that studies the efficacy of academic and co-curricular factors in multiple fields so we can draw conclusions for multiple industries.
#
# Additionally, others examined whether internships directly translate to employment and job advantages. Nunley et al. (2016)<sup><a href="#fn3" id="ref3">3</a></sup> analyze the outcomes of students obtaining internships early on in their career, which is associated with a higher likelihood of receiving a job offer after graduation. This is especially the case when the internship is relevant to the field the student is going into or studying. This demonstrates that internships are a signal to employers of having readily equipped skills that their education alone does not prepare them for. However, this article does not account for how various factors interact across various industries and which of these factors matter more for hiring purposes.
#
# Although prior research highlights the importance of academic and experiential factors, much of the previous research done on this field focuses on a narrow population or focuses on one sole predictor on employability. There is limited work on the importance of applying employability to a larger scale as well as using multiple predictors across various industries using a Data Science approach. Our project aims to address this gap by examining multiple futures like GPA, internship experience, skills, and other factors jointly correlate to employment outcomes. We hope that this project will give insights to students looking for work experience and to guide them in what to focus on in their professional development.
#
# ---
#
# **Footnotes:**
#
# <sup id="fn1">1</sup> Bowling Green State University study. <a href="https://etd.ohiolink.edu/acprod/odb_etd/ws/send_file/send?accession=bgsu1371221438&disposition=inline" target="_blank">Link</a> <a href="#ref1" title="Jump back to footnote 1 in the text.">↩</a>
#
# <sup id="fn2">2</sup> Journal of Vocational Behavior paper. <a href="https://www.sciencedirect.com/science/article/pii/S0001879118301039" target="_blank">Link</a> <a href="#ref2" title="Jump back to footnote 2 in the text.">↩</a>
#
# <sup id="fn3">3</sup> Nunley, J. M., Pugh, A., Romero, N., & Seals, R. A. (2016). College major, internship experience, and employment opportunities: Estimates from a résumé audit. *Labour Economics*, 38, 37-46. <a href="https://EconPapers.repec.org/RePEc:eee:labeco:v:38:y:2016:i:c:p:37-46" target="_blank">Link</a> <a href="#ref3" title="Jump back to footnote 3 in the text.">↩</a>

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Aim: Identify which predictors have the strongest overall association with internship employability.
#
# H0: There is no trait that has a strong association with internship employability
#
#
# H1: There is at least one trait that has a strong association with internship employability

# %% [markdown]
# ## Data

# %% [markdown]
# #### Dataset: Undergraduate Employability
#
#
# GPA: GPA a quantitative variable, which stands for grade point average, represents the student’s overall academic performance across the courses they took. The GPA is on a 10 point scale, but the data comprises GPA ranging from 5-10 with lower numbers indicating a worse GPA (indicating lower grades) and higher numbers indicating a better GPA (higher grades). This is representative of a student’s academic achievement in their classes.
# Research_Participation: This column comprises values 0 or 1, making this a boolean indicator showing whether the student conducted research in their time at school. A 0 indicates no research experience and a 1 indicates the student does have research experience.
# Certification_Count: This is a quantitative variable, and denotes the total number from 0+ of professional or technical certifications (students typically either complete a technical course or pass a test to obtain) the student has passed and received. A higher number indicates more certifications that a student has.
# Project_Experience: This column represents the number of academic or technical industry related projects that the student has completed or worked on. The column is represented with numbers 0+ where higher numbers indicate more projects a student worked on.
# Programming_Skill: The programming skills score reflects the student’s level of proficiency in various programming and coding practices. The given score was measured on a scale of 0-100 with 0 indicating no proficiency in programming and 100 indicating very high proficiency in the skill.
# Tool_Proficiency: This column measures competency in using industry-relevant software, platforms, and technical tools. The given score was measured on a scale of 0-100 with 0 indicating no proficiency in online software tools and 100 indicating very high proficiency in the skill.
# Communication_Skill: This metric scores effectiveness in verbal and written communication. The given score was measured on a scale of 0-100 with 0 indicating no proficiency in communication soft skills and 100 indicating very high proficiency.
# Teamwork_Ability: The given score of this column indicates the student’s ability to collaborate and function effectively within teams. The given score was measured on a scale of 0-100 with 0 indicating no ability in teamwork and 100 indicating very high proficiency in the skill.
# Adaptability: This metric measures a person's ability to adjust to new technologies, environments, or tasks. The given score was measured on a scale of 0-100 with 0 indicating no proficiency in adaptability and 100 indicating very high proficiency in the ability.
# Networking_Activity: This column measures the level of professional networking and career-related interactions. The given score was measured on a scale of 0-100 with 0 indicating no activity in networking and 100 indicating very high activity.
#
#
# ### Major Concerns
# There is little publicly available documentation about where and how this dataset was collected on Kaggle, who the students are, or what institutions they come from, which makes it difficult to assess representativeness. Without the detailed metadata or collection context, it could bias results if the sample is not representative of the broader undergraduate population.
#
# Given the fact that this dataset was contributed by an individual user on Kaggle, if the dataset originates from a specific educational system or type of institution, institution-specific patterns (grading, internship access mechanisms) could drive associations rather than true predictive relationships relevant to the broader tech internship ecosystem, which reduce its power to address our RQ.
#
# Because the dataset documentation does not explicitly describe missing values or preprocessing, there’s a risk of listwise deletion or incomplete cases biasing the analysis if missingness is non-random (e.g., students with worse outcomes might be less likely to report certain attributes).
#
# This dataset on Kaggle is not verified, which weakens the credibility and makes it difficult to evaluate construct validity or sampling integrity. There is probability for data fabrication, which reduces the predictive power for the model based on these data.
#
# The dataset is already clean on Kaggle, so we suspect some other people might have already worked on this data, which might introduce distortion to the data.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/airline-safety/airline-safety.csv', 'filename':'airline-safety.csv'},
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Overall Download Progress:  50%|█████     | 1/2 [00:00<00:00,  5.89it/s]
# Successfully downloaded: airline-safety.csv
# Overall Download Progress: 100%|██████████| 2/2 [00:00<00:00,  8.79it/s]
# Successfully downloaded: bad-drivers.csv

# %% [markdown]
# ### Dataset #1
#
# Instructions: REPLACE the contents of this cell and the one below with your work, including any updates to recover points lost in your data checkpoint feedback

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
import pandas as pd
import numpy as np

data = pd.read_csv("data/00-raw/UECD_1200_dataset.csv")
data.head()
# Out:
#     GPA  Core_Subject_Score  Academic_Consistency  Research_Participation  \
# 0  7.19                66.0                  2.14                     1.0
# 1  9.78                61.0                  1.42                     0.0
# 2  8.79                83.0                  1.22                     0.0
# 3  8.19                65.0                  1.49                     0.0
# 4  6.20                87.0                  2.16                     0.0
#
#    Programming_Skill  Domain_Knowledge  Tool_Proficiency  Certification_Count  \
# 0               48.0              51.0              35.0                  2.0
# 1               70.0              85.0              75.0                  5.0
# 2               54.0              52.0              79.0                  5.0
# 3               43.0              81.0              67.0                  5.0
# 4               79.0              95.0              47.0                  3.0
#
# ...

# %%
data.shape
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   GPA                               1164 non-null   float64
#  1   Core_Subject_Score                1164 non-null   float64
#  2   Academic_Consistency              1164 non-null   float64
#  3   Research_Participation            1164 non-null   float64
#  4   Programming_Skill                 1164 non-null   float64
#  5   Domain_Knowledge                  1164 non-null   float64
#  6   Tool_Proficiency                  1164 non-null   float64
#  7   Certification_Count               1164 non-null   float64
#  8   Internship_Count                  1164 non-null   float64
#  9   Internship_Duration               1164 non-null   float64
#  10  Industry_Relevance                1164 non-null   float64
# ...

# %%
data.describe()
# Out:
#                GPA  Core_Subject_Score  Academic_Consistency  \
# count  1164.000000         1164.000000           1164.000000
# mean      7.750584           74.371134              1.494983
# std       1.319964           11.403099              0.576473
# min       5.520000           55.000000              0.500000
# 25%       6.577500           65.000000              1.020000
# 50%       7.800000           74.000000              1.500000
# 75%       8.892500           84.000000              1.990000
# max      10.000000           94.000000              2.500000
#
#        Research_Participation  Programming_Skill  Domain_Knowledge  \
# count             1164.000000        1164.000000       1164.000000
# mean                 0.265464          68.997423         71.974227
# std                  0.441770          17.299322         16.079051
# min                  0.000000          40.000000         45.000000
# 25%                  0.000000          54.000000         58.000000
# ...

# %%
data.isna().sum()

# %%
# data.isna().sum()
# data.describe()
dropped = data.drop("Employment_Competitiveness_Score", axis=1)
dropped.loc[(dropped.isna().any(axis=1))]

# %%
def prob_impute(df):
    df = df.copy()
    for col in df.columns:
        s = df[col].copy()
        num_null = s.isna().sum()
        fill_vals = np.random.choice(s.dropna(), num_null)
        s[s.isna()] = fill_vals
        df[col] = s
    return df
dropped = prob_impute(dropped)

# %%
dropped["GPA"].plot(kind = 'hist', bins = 20)

# %%
dropped.describe()

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %% [markdown]
# #### Section 1 of EDA - please give it a better title than this
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# #### Section 2 of EDA if you need it  - please give it a better title than this
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Ethics

# %% [markdown]
# ## Ethics
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > Our data will be either taken directly from Kaggle or scraped from LinkedIn. Using the LinkedIn API, we will be using publicly available information such as an individual’s work experience, skillsets, projects, and other profile traits. In doing so, information from each subject is not explicitly consented for, but since we are not asking for new information of them or having to interact with the participant at all, LinkedIn’s API privacy settings and the information that is able to be accessed from there is available for use. Since we might be scraping LinkedIn, every person whose data we will be obtaining data has made this information available for everyone to see. So, while the participants may have consented to putting their information on LinkedIn, they have not explicitly stated consent for their data to be used in the study. We’ll handle issues on a case-by-case basis, eliminating certain variables if we deem them too unsafe or biased.
#
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > We will try to obtain data that is diverse and representative of the unique population we sample and try to factor in social, cultural, and economic backgrounds.
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > Employment outcomes are sometimes shaped by other external factors such as educational, networking, and socioeconomic background which is not represented in the data.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > There could be a lot of biases perpetuated in our data, like how certain demographics are less likely to be hired due to existing prejudice, which we will have to deal with. When we perform our tests and analyses, we’ll be able to spot out variables with high significance that result from human biases.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > We will try to select accurate and thoughtful data visualizations.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > There is the instance that we are comparing job qualifications to people who have jobs already and we acknowledge that it is difficult to get data and therefore research the alternative side of people with certain skill sets failing to get certain jobs.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
#  > We will compare model performance across the various groups and report any disparities between them.
#
#  - [ ] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [ ] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
#  > Our prediction model could be misused and could either give false hope or a false alarm to those using the model externally outside of this project, depending on a positive or negative outcome. We acknowledge that the model is for academic purposes and not to be applied in a real-life scenario or job hiring decision-making.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * *We will meet up in person when we first start a project segment. From there, we will discuss how to carry out each part of the project and delegate tasks accordingly.*
# * *If we are unable to complete the assignment during our scheduled in-person meetings, we will finish our assigned tasks on our own time by the due date to the best of our ability.*
# * *We will be open-minded to other people’s ideas and perspectives about the project and be open to feedback from one another. We will also be communicative about our progress in the project through our in-person meetings or through our text message group chat.*
# * *If any conflicts arise, we will try our best to work them through by communicating or trying various solutions, making sure to hear out both sides of the argument.*

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 1/28  |  5 PM | Review prior project ideas and constraints; individually think about general project topic  | Work on previous project review assignment; brainstorm project topic and scope; decide primary communication method; agree on research question and high-level hypotheses; assign background research |
# | 2/1  |  5 PM |  Background research on academic and experiential predictors of employment; review prior work on internship efficacy and GPA-employment correlations; summarize relevant paper | Discuss prior work findings; refine hypotheses (Aim1: Predictor × industry interactions & Aim 2: Relative importance of experience vs. GPA); Discuss ethical concerns specific to LinkedIn and job-posting data (privacy, consent, bias); Identify ideal student-profile and job-listing datasets |
# | 2/3  | 5 PM  | Edit, finalize, and submit proposal; Search for Kaggle datasets and assess LinkedIn scraping feasibility  | Edit and finalize proposal for submission; evaluate dataset feasibility; discuss data wrangling needs and possible analytical approaches; assign task leads (data, EDA, modeling, writing)   |
# | 2/14  | 6 PM  | Import and clean raw datasets; begin EDA | Review wrangling and EDA; assess data quality and industry balance; finalize modeling plan (logistic regression + industry interactions)   |
# | 2/17  | 5 PM  | Summarize searched dataset size, features, and constraints | DWork on Data Checkpoint together and submit for review |
# | 2/23  | 5 PM  | Finalize data wrangling and EDA; begin modeling and hypothesis testing| Review preliminary results; evaluate GPA vs experience effects; refine models; complete project check-in |
# | 3/3  | 5 PM  | Work on markdown text and code for current EDA process and results | Complete the EDA Checkpoint and submit it for review |
# | 3/13  | 5 PM  | Complete all analysis; draft results, conclusion, discussion; write scripts for final video | Review and edit full project draft; refine figures and tables; ensure ethical considerations are clearly addressed; shoot the video |
# | 3/18  | Before 11:59 PM  | Finish final revisions; prepare all submission materials | Turn in Final Project & Group Project Surveys |
